# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

import requests
from bs4 import BeautifulSoup

# %%
pd.read_csv ('school_expenditure_perstudent.csv')
# Out:
#                                            Table S-11  \
# 0   Expenditures per Pupil for Elementary and Seco...
# 1                                                 NaN
# 2                                               State
# 3                                       United States
# 4                                             Alabama
# ..                                                ...
# 58  NOTES: The national total for public school ex...
# 59  SOURCE: National Center for Education Statisti...
# 60  Recommended Citation: National Science Board. ...
# 61                       Last updated: April 29, 2020
# 62                 Science and Engineering Indicators
#
#                                  Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                                       NaN          NaN          NaN
# 1   Public school expenditures ($thousands)          NaN          NaN
# 2                                      1993         1994         1995
# ...
